# %% [markdown]
# # wildspoof_challenge_benchmark_processed_ssboll79

# %%
import pandas as pd

asv19df = pd.read_csv('/nvme2/hungdx/Lightning-hydra/data/wildspoof_challenge_benchmark_processed_ssboll79/Wild_Spoof_Dataset/protocol.txt', sep=' ', header=None)
asv19df.columns = ['utt_id', 'subset', 'label']

# Insert _ssboll79 to the utt_id (utt_id is filename.extension so we need to insert it before the extension)
asv19df['utt_id'] = asv19df['utt_id'].apply(lambda x: x.split('.')[0] + '_ssboll79.' + x.split('.')[1])

asv19df.head()

asv19df.to_csv('/nvme2/hungdx/Lightning-hydra/data/wildspoof_challenge_benchmark_processed_ssboll79/Wild_Spoof_Dataset/protocol.txt', index=False, header=False, sep=' ')
